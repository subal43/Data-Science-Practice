# %%
class SuLR:
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):
    
            
    def predict(self,X_test):
        pass

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df.sample(5)
# Out:
#      cgpa  package
# 130  6.68     2.49
# 113  6.94     2.37
# 171  8.01     3.76
# 185  6.31     3.18
# 148  7.57     3.40
